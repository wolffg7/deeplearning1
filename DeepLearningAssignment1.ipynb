# %%
import numpy as np 
from PIL import Image 

img = Image.open('funny-dogs-stung-by-bees-5-5c877ddb86bf7__700.jpg') 
pixels = img.load() 
for i in range(30): 
  for j in range(30): 
    pixels[-i, j] = (0,0,0) 
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x955 at 0x7F7DCB4E3DF0>
